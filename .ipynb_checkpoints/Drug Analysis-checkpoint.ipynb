# %%
import numpy as np
import pandas as pd
import itertools as it
import matplotlib.pyplot as plt
import networkx as nx

# %%
co_offending_table = pd.read_csv('./Cooffending.csv')
co_offending_table.drop_duplicates(inplace=True)
co_offending_table.sort_values(by='NoUnique', inplace=True)
def to_int(x):
    if x == ' ':
        return 0
    else:
        return int(x)
co_offending_table.NCD1 = co_offending_table.NCD1.apply(to_int)
co_offending_table.NCD1 = co_offending_table.NCD1.astype(int)

# %%
crime_labels = pd.read_csv('./crime_type_mapping.csv')

# %%
co_offending_table_with_crime_labels = pd.merge(co_offending_table, crime_labels, left_on='NCD1', 
                                                right_on='crime_code', how='left')

# %%
co_offending_table_with_crime_labels['crime'] = 1

# %%
co_offending_table_with_crime_labels['crime_count'] = co_offending_table_with_crime_labels.groupby('NoUnique')['crime'].transform('sum')

# %%
co_offending_table_with_crime_labels['drug_crime_count'] = co_offending_table_with_crime_labels.groupby('NoUnique')['drug_crime'].transform('sum')

# %%
co_offending_table_with_crime_labels['drug_usage_count'] = co_offending_table_with_crime_labels.groupby('NoUnique')['drug_usage'].transform('sum')

# %%
co_offending_table_with_crime_labels['drug_trafficking_count'] = co_offending_table_with_crime_labels.groupby('NoUnique')['drug_trafficking'].transform('sum')

# %%
co_offending_table_with_crime_labels['other_crime_count'] = co_offending_table_with_crime_labels['crime_count'] - co_offending_table_with_crime_labels['drug_crime_count']

# %%
co_offending_table_with_crime_labels['percent_traffic'] = co_offending_table_with_crime_labels['drug_trafficking_count']/co_offending_table_with_crime_labels['crime_count']

# %%
co_offending_table_with_crime_labels['percent_usage'] = co_offending_table_with_crime_labels['drug_usage_count']/co_offending_table_with_crime_labels['crime_count']

# %%
co_offending_table_with_crime_labels['percent_other'] = co_offending_table_with_crime_labels['other_crime_count']/co_offending_table_with_crime_labels['crime_count']

# %%
drug_related = co_offending_table_with_crime_labels[co_offending_table_with_crime_labels.drug_crime > 0]

# %%
for offender in np.unique(drug_related.NoUnique)[1:10]:
    crimes = co_offending_table_with_crime_labels[co_offending_table_with_crime_labels.NoUnique == offender].head(1)
    c
    print(crimes)
# Out:
#       NoUnique  Naissance SEXE    SeqE   dateInf  NCD1 NCD2 NCD3 NCD4    MUN  \
# 1327      1546       1907    M  501266  20061009  4130                 66023
#
#             ...         group_crime  drug_crime  drug_usage drug_trafficking  \
# 1327        ...                 1.0         1.0         1.0              0.0
#
#       drug_crime_count  drug_usage_count drug_trafficking_count crime  \
# 1327               1.0               1.0                    0.0     1
#
#       crime_count  other_crime_count
# 1327            1                0.0
#
# [1 rows x 28 columns]
#       NoUnique  Naissance SEXE    SeqE   dateInf  NCD1 NCD2 NCD3 NCD4    MUN  \
# 1328      1547       1907    M  501266  20061009  4130                 66023
#
#             ...         group_crime  drug_crime  drug_usage drug_trafficking  \
# 1328        ...                 1.0         1.0         1.0              0.0
#
#       drug_crime_count  drug_usage_count drug_trafficking_count crime  \
# 1328               1.0               1.0                    0.0     1
#
#       crime_count  other_crime_count
# 1328            1                0.0
#
# [1 rows x 28 columns]
#       NoUnique  Naissance SEXE    SeqE   dateInf  NCD1 NCD2 NCD3 NCD4    MUN  \
# 3647      3722       1910    F  778213  20070410  4530                 66023
#
#             ...         group_crime  drug_crime  drug_usage drug_trafficking  \
# 3647        ...                 0.0         1.0         1.0              1.0
#
#       drug_crime_count  drug_usage_count drug_trafficking_count crime  \
# 3647               1.0               1.0                    1.0     1
#
#       crime_count  other_crime_count
# 3647            1                0.0
#
# [1 rows x 28 columns]
#       NoUnique  Naissance SEXE   SeqE   dateInf  NCD1 NCD2 NCD3 NCD4    MUN  \
# 4007      4083       1911    M  22740  20090823  4140                 66097
#
#             ...         group_crime  drug_crime  drug_usage drug_trafficking  \
# 4007        ...                 1.0         1.0         1.0              0.0
#
#       drug_crime_count  drug_usage_count drug_trafficking_count crime  \
# 4007               1.0               1.0                    0.0     1
#
#       crime_count  other_crime_count
# 4007            1                0.0
#
# [1 rows x 28 columns]
#       NoUnique  Naissance SEXE    SeqE   dateInf   NCD1  NCD2   NCD3 NCD4  \
# 4303      4762       1920    M  346859  20041007  42401  4140  44402
#
#         MUN        ...         group_crime  drug_crime  drug_usage  \
# 4303  52040        ...                 1.0         1.0         0.0
#
#      drug_trafficking  drug_crime_count  drug_usage_count  \
# 4303              1.0               1.0               0.0
#
#      drug_trafficking_count crime  crime_count  other_crime_count
# 4303                    1.0     1            2                1.0
#
# [1 rows x 28 columns]
#       NoUnique  Naissance SEXE     SeqE   dateInf  NCD1 NCD2 NCD3 NCD4    MUN  \
# 4617      5275       1922    F  1008658  20090224  4130                 81017
#
#             ...         group_crime  drug_crime  drug_usage drug_trafficking  \
# 4617        ...                 1.0         1.0         1.0              0.0
#
#       drug_crime_count  drug_usage_count drug_trafficking_count crime  \
# 4617               1.0               1.0                    0.0     1
#
#       crime_count  other_crime_count
# 4617            1                0.0
#
# [1 rows x 28 columns]
#       NoUnique  Naissance SEXE    SeqE   dateInf  NCD1  NCD2 NCD3 NCD4    MUN  \
# 4866      5722       1923    M  383353  20041023  4130  4140            76052
#
#             ...         group_crime  drug_crime  drug_usage drug_trafficking  \
# 4866        ...                 1.0         1.0         1.0              0.0
#
#       drug_crime_count  drug_usage_count drug_trafficking_count crime  \
# 4866               1.0               1.0                    0.0     1
#
#       crime_count  other_crime_count
# 4866            1                0.0
#
# [1 rows x 28 columns]
#       NoUnique  Naissance SEXE    SeqE   dateInf  NCD1 NCD2 NCD3 NCD4    MUN  \
# 4877      5735       1923    M  125562  20060617  4140                 70052
#
#             ...         group_crime  drug_crime  drug_usage drug_trafficking  \
# 4877        ...                 1.0         1.0         1.0              0.0
#
#       drug_crime_count  drug_usage_count drug_trafficking_count crime  \
# 4877               3.0               2.0                    1.0     1
#
#       crime_count  other_crime_count
# 4877           10                7.0
#
# [1 rows x 28 columns]
#       NoUnique  Naissance SEXE    SeqE   dateInf  NCD1 NCD2 NCD3 NCD4    MUN  \
# 5487      6690       1925    F  875822  20051025  4220                 89008
#
#             ...         group_crime  drug_crime  drug_usage drug_trafficking  \
# 5487        ...                 1.0         1.0         0.0              1.0
#
#       drug_crime_count  drug_usage_count drug_trafficking_count crime  \
# 5487               1.0               0.0                    1.0     1
#
#       crime_count  other_crime_count
# 5487            1                0.0
#
# [1 rows x 28 columns]

# %%
drug_crime_graph = nx.Graph()

for crime_seq in drug_related.SeqE:
# Out:
#          NoUnique  Naissance SEXE     SeqE   dateInf   NCD1   NCD2   NCD3  \
# 888          1152       1906    M  1582337  20050106  42401  44402
# 1327         1546       1907    M   501266  20061009   4130
# 1328         1547       1907    M   501266  20061009   4130
# 3647         3722       1910    F   778213  20070410   4530
# 4007         4083       1911    M    22740  20090823   4140
# 4303         4762       1920    M   346859  20041007  42401   4140  44402
# 4617         5275       1922    F  1008658  20090224   4130
# 4866         5722       1923    M   383353  20041023   4130   4140
# 4877         5735       1923    M   125562  20060617   4140
# 4880         5735       1923    M   128530  20080416   4220   4230   4240
# 4881         5735       1923    M   124838  20060120   4140
# 5487         6690       1925    F   875822  20051025   4220
# 5539         6761       1926    M    72690  20040720  44402
# 5698         6974       1926    M  1191693  20030426   4140
# 5716         6993       1926    M   539228  20050225   4140
# 5798         7130       1926    M   491054  20030722  42201  42401   4120
# 6020         7463       1927    M   389945  20030606   4140
# 6466         7809       1927    F   507484  20090414   4220  42201  42302
# 6741         8210       1928    M    67316  20040511  44402
# 6844         8351       1928    M  1144482  20030906  44402
# 6900         8430       1928    F   970751  20040513   4220
# 6926         8455       1928    M   754187  20030411  42201
# 7139         8745       1929    M   946683  20030422  42401  44402
# 7181         8804       1929    F   347508  20060529   4340
# 7218         8859       1929    F   777228  20070114   4530
# 7230         8870       1929    M   344191  20060315  44401
# 7237         8882       1929    F    77367  20080927  42401
# 7278         8947       1929    M   876127  20071030  42401
# 7346         9049       1929    M  1554568  20060831  44402
# 7358         9060       1929    M   716194  20031204  42201  42301  42401
# ...           ...        ...  ...      ...       ...    ...    ...    ...
# 1277176    668160       1997    M  1558513  20091104   4140
# 1277194    668175       1997    M   171422  20091116   4140
# 1277231    668203       1997    M  1001540  20080507   4140
# 1277239    668210       1997    M  1366624  20091008   4140
# 1277252    668221       1997    F  1223505  20090508   4140
# 1277281    668246       1997    M  1520857  20090924   4140
# 1277307    668268       1997    M   221694  20081118   4140
# 1277362    668314       1997    M   183226  20081017   4140
# 1277428    668366       1997    M  1520857  20090924   4140
# 1277437    668375       1997    M  1408715  20091014   4240
# 1277474    668404       1997    M  1340721  20091214   4140
# 1277532    668452       1997    M   178700  20080615   4240
# 1277566    668478       1997    M  1411887  20061101   4140
# 1277573    668482       1997    M  1001540  20080507   4140
# 1277574    668483       1997    M   689845  20091020   4140
# 1277610    668509       1997    M  1435968  20090923   4140
# 1277675    668564       1997    M   862603  20081006   4140
# 1277781    668647       1997    M  1625207  20090910   4140
# 1277790    668655       1997    M  1464734  20071206   4140
# 1277792    668657       1997    M   874662  20071009   4140
# 1278156    668956       1998    F   171183  20090928   4140
# 1278375    669141       1998    M   874662  20071009   4140
# 1278452    669199       1998    M   211646  20090120   4240   4140
# 1278551    669285       1998    M   537235  20090326   4140
# 1278790    669486       1998    M   263370  20090204   4140
# 1278801    669497       1998    M   206976  20080924   4140
# 1278867    669545       1999    M  1427918  20070402  42301
# 1278944    669608       1999    M  1625207  20090910   4140
# 1279136    669774       1999    M   211646  20090120   4240   4140
# 1279242    669865       1999    M   752841  20080213   4140
#
#           NCD4    MUN        ...         group_crime  drug_crime  drug_usage  \
# 888             64008        ...                 1.0         1.0         0.0
# 1327            66023        ...                 1.0         1.0         1.0
# 1328            66023        ...                 1.0         1.0         1.0
# 3647            66023        ...                 0.0         1.0         1.0
# 4007            66097        ...                 1.0         1.0         1.0
# 4303            52040        ...                 1.0         1.0         0.0
# 4617            81017        ...                 1.0         1.0         1.0
# 4866            76052        ...                 1.0         1.0         1.0
# 4877            70052        ...                 1.0         1.0         1.0
# 4880            70052        ...                 1.0         1.0         0.0
# 4881            70052        ...                 1.0         1.0         1.0
# 5487            89008        ...                 1.0         1.0         0.0
# 5539            46050        ...                 1.0         1.0         0.0
# 5698            25213        ...                 1.0         1.0         1.0
# 5716            66023        ...                 1.0         1.0         1.0
# 5798     44402  21025        ...                 1.0         1.0         0.0
# 6020            78102        ...                 1.0         1.0         1.0
# 6466            66023        ...                 1.0         1.0         0.0
# 6741            71133        ...                 1.0         1.0         0.0
# 6844            65005        ...                 1.0         1.0         0.0
# 6900            81017        ...                 1.0         1.0         0.0
# 6926            95032        ...                 1.0         1.0         0.0
# 7139            72005        ...                 1.0         1.0         0.0
# 7181            52080        ...                 1.0         1.0         0.0
# 7218            66023        ...                 0.0         1.0         1.0
# 7230            37245        ...                 1.0         1.0         0.0
# 7237            46080        ...                 1.0         1.0         0.0
# 7278            79010        ...                 1.0         1.0         0.0
# 7346            45075        ...                 1.0         1.0         0.0
# 7358            68005        ...                 1.0         1.0         0.0
# ...        ...    ...        ...                 ...         ...         ...
# 1277176         45072        ...                 1.0         1.0         1.0
# 1277194         49058        ...                 1.0         1.0         1.0
# 1277231         81017        ...                 1.0         1.0         1.0
# 1277239         12072        ...                 1.0         1.0         1.0
# 1277252         74005        ...                 1.0         1.0         1.0
# 1277281         56083        ...                 1.0         1.0         1.0
# 1277307         66023        ...                 1.0         1.0         1.0
# 1277362         42100        ...                 1.0         1.0         1.0
# 1277428         56083        ...                 1.0         1.0         1.0
# 1277437         57005        ...                 1.0         1.0         0.0
# 1277474         23027        ...                 1.0         1.0         1.0
# 1277532         50072        ...                 1.0         1.0         0.0
# 1277566         73010        ...                 1.0         1.0         1.0
# 1277573         81017        ...                 1.0         1.0         1.0
# 1277574          8053        ...                 1.0         1.0         1.0
# 1277610         94068        ...                 1.0         1.0         1.0
# 1277675         66023        ...                 1.0         1.0         1.0
# 1277781         37067        ...                 1.0         1.0         1.0
# 1277790         43027        ...                 1.0         1.0         1.0
# 1277792         75028        ...                 1.0         1.0         1.0
# 1278156         49058        ...                 1.0         1.0         1.0
# 1278375         75028        ...                 1.0         1.0         1.0
# 1278452         40043        ...                 1.0         1.0         0.0
# 1278551         98015        ...                 1.0         1.0         1.0
# 1278790         87090        ...                 1.0         1.0         1.0
# 1278801         39025        ...                 1.0         1.0         1.0
# 1278867         94068        ...                 1.0         1.0         0.0
# 1278944         37067        ...                 1.0         1.0         1.0
# 1279136         40043        ...                 1.0         1.0         0.0
# 1279242         51080        ...                 1.0         1.0         1.0
#
#         drug_trafficking  drug_crime_count  drug_usage_count  \
# 888                  1.0               1.0               0.0
# 1327                 0.0               1.0               1.0
# 1328                 0.0               1.0               1.0
# 3647                 1.0               1.0               1.0
# 4007                 0.0               1.0               1.0
# 4303                 1.0               1.0               0.0
# 4617                 0.0               1.0               1.0
# 4866                 0.0               1.0               1.0
# 4877                 0.0               3.0               2.0
# 4880                 1.0               3.0               2.0
# 4881                 0.0               3.0               2.0
# 5487                 1.0               1.0               0.0
# 5539                 1.0               1.0               0.0
# 5698                 0.0               1.0               1.0
# 5716                 0.0               1.0               1.0
# 5798                 1.0               1.0               0.0
# 6020                 0.0               1.0               1.0
# 6466                 1.0               1.0               0.0
# 6741                 1.0               1.0               0.0
# 6844                 1.0               1.0               0.0
# 6900                 1.0               1.0               0.0
# 6926                 1.0               1.0               0.0
# 7139                 1.0               1.0               0.0
# 7181                 1.0               1.0               0.0
# 7218                 1.0               1.0               1.0
# 7230                 1.0               1.0               0.0
# 7237                 1.0               1.0               0.0
# 7278                 1.0               1.0               0.0
# 7346                 1.0               1.0               0.0
# 7358                 1.0               1.0               0.0
# ...                  ...               ...               ...
# 1277176              0.0               1.0               1.0
# 1277194              0.0               1.0               1.0
# 1277231              0.0               1.0               1.0
# 1277239              0.0               1.0               1.0
# 1277252              0.0               1.0               1.0
# 1277281              0.0               1.0               1.0
# 1277307              0.0               1.0               1.0
# 1277362              0.0               1.0               1.0
# 1277428              0.0               1.0               1.0
# 1277437              1.0               1.0               0.0
# 1277474              0.0               1.0               1.0
# 1277532              1.0               1.0               0.0
# 1277566              0.0               1.0               1.0
# 1277573              0.0               1.0               1.0
# 1277574              0.0               1.0               1.0
# 1277610              0.0               1.0               1.0
# 1277675              0.0               1.0               1.0
# 1277781              0.0               1.0               1.0
# 1277790              0.0               1.0               1.0
# 1277792              0.0               1.0               1.0
# 1278156              0.0               1.0               1.0
# 1278375              0.0               1.0               1.0
# 1278452              1.0               1.0               0.0
# 1278551              0.0               1.0               1.0
# 1278790              0.0               1.0               1.0
# 1278801              0.0               1.0               1.0
# 1278867              1.0               1.0               0.0
# 1278944              0.0               1.0               1.0
# 1279136              1.0               1.0               0.0
# 1279242              0.0               1.0               1.0
#
#         drug_trafficking_count crime  crime_count  other_crime_count
# 888                        1.0     1            1                0.0
# 1327                       0.0     1            1                0.0
# 1328                       0.0     1            1                0.0
# 3647                       1.0     1            1                0.0
# 4007                       0.0     1            1                0.0
# 4303                       1.0     1            2                1.0
# 4617                       0.0     1            1                0.0
# 4866                       0.0     1            1                0.0
# 4877                       1.0     1           10                7.0
# 4880                       1.0     1           10                7.0
# 4881                       1.0     1           10                7.0
# 5487                       1.0     1            1                0.0
# 5539                       1.0     1            1                0.0
# 5698                       0.0     1            1                0.0
# 5716                       0.0     1            1                0.0
# 5798                       1.0     1            2                1.0
# 6020                       0.0     1            1                0.0
# 6466                       1.0     1            1                0.0
# 6741                       1.0     1            1                0.0
# 6844                       1.0     1            1                0.0
# 6900                       1.0     1            1                0.0
# 6926                       1.0     1            1                0.0
# 7139                       1.0     1            1                0.0
# 7181                       1.0     1            1                0.0
# 7218                       1.0     1            1                0.0
# 7230                       1.0     1            1                0.0
# 7237                       1.0     1            1                0.0
# 7278                       1.0     1            1                0.0
# 7346                       1.0     1            1                0.0
# 7358                       1.0     1            1                0.0
# ...                        ...   ...          ...                ...
# 1277176                    0.0     1            1                0.0
# 1277194                    0.0     1            2                1.0
# 1277231                    0.0     1            1                0.0
# 1277239                    0.0     1            1                0.0
# 1277252                    0.0     1            1                0.0
# 1277281                    0.0     1            1                0.0
# 1277307                    0.0     1            1                0.0
# 1277362                    0.0     1            1                0.0
# 1277428                    0.0     1            1                0.0
# 1277437                    1.0     1            2                1.0
# 1277474                    0.0     1            1                0.0
# 1277532                    1.0     1            1                0.0
# 1277566                    0.0     1            1                0.0
# 1277573                    0.0     1            1                0.0
# 1277574                    0.0     1            1                0.0
# 1277610                    0.0     1            1                0.0
# 1277675                    0.0     1            2                1.0
# 1277781                    0.0     1            1                0.0
# 1277790                    0.0     1            1                0.0
# 1277792                    0.0     1            1                0.0
# 1278156                    0.0     1            1                0.0
# 1278375                    0.0     1            1                0.0
# 1278452                    1.0     1            1                0.0
# 1278551                    0.0     1            1                0.0
# 1278790                    0.0     1            4                3.0
# 1278801                    0.0     1            1                0.0
# 1278867                    1.0     1            2                1.0
# 1278944                    0.0     1            1                0.0
# 1279136                    1.0     1            1                0.0
# 1279242                    0.0     1            1                0.0
#
# [100090 rows x 28 columns]

# %%
crime_labels[crime_labels.crime_code == 3375]
# Out:
#     crime_code     text_description criminology_category  group_crime  \
# 75        3375  POSSESSION D''ARMES                    3            1
#
#     drug_crime  drug_usage  drug_trafficking
# 75           0           0                 0

# %%
drug_crimes = co_offending_table_with_crime_labels.drug_crime == 1.0
co_offending_table_drugs_only = co_offending_table_with_crime_labels[drug_crimes]

# %%
co_offender_graph_drugs_only = nx.Graph()
i = 1
for crime_event in np.unique(co_offending_table_drugs_only.SeqE.values):
    if i % 10000 == 0:
        print(i)
    offenders_arrested_together = co_offending_table_drugs_only[co_offending_table_drugs_only.SeqE == crime_event]['NoUnique'].values 
    for offender1 in offenders_arrested_together:
        for offender2 in offenders_arrested_together:
            if offender1 != offender2:
                # so we get only one edge without any weight
                co_offender_graph_drugs_only.add_edge(offender1, offender2)
    i+=1
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000

# %%
largest_component_graph = max(nx.connected_component_subgraphs(co_offender_graph_drugs_only), key=len)

# %%
len(largest_component_graph.nodes())
# Out:
# 188

# %%
nodes = largest_component_graph.nodes()

# %%
colors = [co_offending_table_with_crime_labels[co_offending_table_with_crime_labels.NoUnique == i]['percent_traffic'].values[0] for i in nodes]

# %%
colors = ['blue' if x > 0.5 else 'red' for x in colors]

# %%
colors
# Out:
# ['blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'blue']

# %%
pos = nx.spring_layout(largest_component_graph)
#sm = nx.draw_networkx_nodes(largest_component_graph, pos, nodelist=nodes, node_color=colors, cmap=plt.cm.Blues, node_size=100)
#nx.draw_networkx_edges(largest_component_graph, pos, nodelist=nodes, node_color=colors, cmap=plt.cm.Blues)
#plt.colorbar(sm)
nx.draw(largest_component_graph, nodelist=nodes, node_color=colors)
plt.show()
# Out:
# /Users/henryaspegren/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /Users/henryaspegren/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /Users/henryaspegren/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# /Users/henryaspegren/anaconda3/lib/python3.6/site-packages/matplotlib/rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")
